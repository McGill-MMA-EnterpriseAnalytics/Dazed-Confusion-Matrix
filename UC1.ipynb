# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime

# %%
bpd_df = pd.read_csv('BPD_CRIME_DATA_CLEAN_ST.csv')

# %%
bpd_df.head()
# Out:
#     CrimeDate CrimeTime CrimeCode           Location          Description  \
# 0  2017-09-02  23:30:00       3JK    4200 AUDREY AVE  ROBBERY - RESIDENCE
# 1  2017-09-02  23:00:00        7A  800 NEWINGTON AVE           AUTO THEFT
# 2  2017-09-02  22:53:00        9S      600 RADNOR AV             SHOOTING
# 3  2017-09-02  22:50:00        4C     1800 RAMSAY ST         AGG. ASSAULT
# 4  2017-09-02  22:31:00        4E       100 LIGHT ST       COMMON ASSAULT
#
#   Inside/Outside   Weapon   Post  District      Neighborhood  longitude  \
# 0         Inside    KNIFE  913.0  SOUTHERN          Brooklyn   -76.6054
# 1        Outside     NONE  133.0   CENTRAL    Reservoir Hill   -76.6322
# 2        Outside  FIREARM  524.0  NORTHERN    Winston-Govans   -76.6070
# 3         Inside    OTHER  934.0  SOUTHERN  Carrollton Ridge   -76.6453
# 4        Outside    HANDS  113.0   CENTRAL     Downtown West   -76.6137
#
#    latitude                       Location 1     Premise  Total Incidents  \
# ...
