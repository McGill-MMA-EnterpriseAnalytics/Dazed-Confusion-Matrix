# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/BPD_CRIME_DATA_WITHDEMOGRAPHICS.csv")

# %%
df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1           Description Inside/Outside   Weapon  \
# 0            0             0   ROBBERY - RESIDENCE         Inside    KNIFE
# 1            1             1            AUTO THEFT        Outside     NONE
# 2            2             2              SHOOTING        Outside  FIREARM
# 3            3             3          AGG. ASSAULT         Inside    OTHER
# 4            4             4        COMMON ASSAULT        Outside    HANDS
# 5            5             5              BURGLARY         Inside     NONE
# 6            6             6              HOMICIDE        Outside  FIREARM
# 7            7             7      ROBBERY - STREET        Outside     NONE
# 8            8             8          AGG. ASSAULT        Outside    OTHER
# 9            9             9        COMMON ASSAULT         Inside    HANDS
# 10          10            10          AGG. ASSAULT        Outside    OTHER
# 11          11            11  ROBBERY - COMMERCIAL         Inside  FIREARM
# 12          12            13          AGG. ASSAULT        Outside    OTHER
# 13          13            14     LARCENY FROM AUTO        Outside     NONE
# 14          14            15              BURGLARY         Inside     NONE
# 15          15            16              SHOOTING        Outside  FIREARM
# 16          16            17              HOMICIDE        Outside  FIREARM
# 17          17            18        COMMON ASSAULT        Outside    HANDS
# 18          18            19               LARCENY         Inside     NONE
# 19          19            20              BURGLARY         Inside     NONE
#
#      Post      District              Neighborhood  Longitude  Latitude  ...  \
# 0   913.0      SOUTHERN                  Brooklyn  -76.60541  39.22951  ...
# 1   133.0       CENTRAL            Reservoir Hill  -76.63217  39.31360  ...
# 2   524.0      NORTHERN            Winston-Govans  -76.60697  39.34768  ...
# 3   934.0      SOUTHERN          Carrollton Ridge  -76.64526  39.28315  ...
# 4   113.0       CENTRAL             Downtown West  -76.61365  39.28756  ...
# 5   922.0      SOUTHERN               Cherry Hill  -76.62131  39.24867  ...
# 6   232.0  SOUTHEASTERN                    Canton  -76.56827  39.28202  ...
# 7   123.0       CENTRAL                     Upton  -76.62789  39.30254  ...
# 8   641.0  NORTHWESTERN             Windsor Hills  -76.68365  39.31370  ...
# 9   332.0       EASTERN                     Berea  -76.57419  39.30551  ...
# 10  641.0  NORTHWESTERN             Windsor Hills  -76.68365  39.31370  ...
# 11  844.0  SOUTHWESTERN                  Edgewood  -76.67759  39.29402  ...
# 12  641.0  NORTHWESTERN             Windsor Hills  -76.68169  39.31400  ...
# 13  444.0  NORTHEASTERN                 Frankford  -76.54270  39.33288  ...
# 14  243.0  SOUTHEASTERN  Holabird Industrial Park  -76.53557  39.26533  ...
# 15  343.0       EASTERN                    Oliver  -76.60246  39.31038  ...
# 16  343.0       EASTERN                    Oliver  -76.60246  39.31038  ...
# 17  132.0       CENTRAL              Madison Park  -76.62256  39.30083  ...
# 18  212.0  SOUTHEASTERN           Washington Hill  -76.59390  39.29020  ...
# 19  426.0  NORTHEASTERN                Waltherson  -76.55734  39.33643  ...
#
#    households_below_poverty  perc18_24  perc25_64   perc65up  perc_asian  \
# 0                 24.213606   8.248062  57.449612   7.302326    2.527132
# 1                 25.964546   8.231621  56.940108  11.003879    0.624468
# 2                       NaN        NaN        NaN        NaN         NaN
# 3                       NaN        NaN        NaN        NaN         NaN
# 4                       NaN        NaN        NaN        NaN         NaN
# 5                 39.337017   9.134854  45.575112   9.779375    0.929598
# 6                  3.661784   5.849147  75.246217  10.533269    4.383858
# 7                 42.982456  11.429971  47.277179  10.803134    1.860921
# 8                       NaN        NaN        NaN        NaN         NaN
# 9                 27.649528   8.788912  52.139479  15.157848    0.417996
# 10                      NaN        NaN        NaN        NaN         NaN
# 11                      NaN        NaN        NaN        NaN         NaN
# 12                      NaN        NaN        NaN        NaN         NaN
# 13                12.182141   8.958899  59.311311  10.003397    3.549592
# 14                      NaN        NaN        NaN        NaN         NaN
# 15                      NaN        NaN        NaN        NaN         NaN
# 16                      NaN        NaN        NaN        NaN         NaN
# 17                      NaN        NaN        NaN        NaN         NaN
# 18                      NaN        NaN        NaN        NaN         NaN
# 19                      NaN        NaN        NaN        NaN         NaN
#
#       perc_aa  perc_hisp       pwhi  num_households  median_price_homes_sold
# 0   37.961240  14.906977  39.682171             NaN                  52000.0
# 1   83.990917   2.876336  10.966033             NaN                 127500.0
# 2         NaN        NaN        NaN             NaN                      NaN
# 3         NaN        NaN        NaN             NaN                      NaN
# 4         NaN        NaN        NaN             NaN                      NaN
# 5   87.469013   5.813089   4.362915             NaN                  45000.0
# 6    3.939467   3.086716  85.575306             NaN                 306500.0
# 7   91.635651   0.636631   4.221352             NaN                 100000.0
# 8         NaN        NaN        NaN             NaN                      NaN
# 9   93.664063   2.034980   2.364976             NaN                  42786.0
# 10        NaN        NaN        NaN             NaN                      NaN
# 11        NaN        NaN        NaN             NaN                      NaN
# 12        NaN        NaN        NaN             NaN                      NaN
# 13  80.566406   3.324558  11.714504             NaN                 112750.0
# 14        NaN        NaN        NaN             NaN                      NaN
# 15        NaN        NaN        NaN             NaN                      NaN
# 16        NaN        NaN        NaN             NaN                      NaN
# 17        NaN        NaN        NaN             NaN                      NaN
# 18        NaN        NaN        NaN             NaN                      NaN
# 19        NaN        NaN        NaN             NaN                      NaN
#
# [20 rows x 27 columns]

# %%
df = df.drop(columns=["Unnamed: 0","Unnamed: 0.1"])

# %%
df.head()
# Out:
#            Description Inside/Outside   Weapon   Post  District  \
# 0  ROBBERY - RESIDENCE         Inside    KNIFE  913.0  SOUTHERN
# 1           AUTO THEFT        Outside     NONE  133.0   CENTRAL
# 2             SHOOTING        Outside  FIREARM  524.0  NORTHERN
# 3         AGG. ASSAULT         Inside    OTHER  934.0  SOUTHERN
# 4       COMMON ASSAULT        Outside    HANDS  113.0   CENTRAL
#
#        Neighborhood  Longitude  Latitude     Premise  Season  ...  \
# 0          Brooklyn  -76.60541  39.22951  ROW/TOWNHO  summer  ...
# 1    Reservoir Hill  -76.63217  39.31360      STREET  summer  ...
# 2    Winston-Govans  -76.60697  39.34768      STREET  summer  ...
# 3  Carrollton Ridge  -76.64526  39.28315  ROW/TOWNHO  summer  ...
# 4     Downtown West  -76.61365  39.28756      STREET  summer  ...
#
#    households_below_poverty  perc18_24  perc25_64   perc65up  perc_asian  \
# 0                 24.213606   8.248062  57.449612   7.302326    2.527132
# 1                 25.964546   8.231621  56.940108  11.003879    0.624468
# 2                       NaN        NaN        NaN        NaN         NaN
# 3                       NaN        NaN        NaN        NaN         NaN
# 4                       NaN        NaN        NaN        NaN         NaN
#
#      perc_aa  perc_hisp       pwhi  num_households  median_price_homes_sold
# 0  37.961240  14.906977  39.682171             NaN                  52000.0
# 1  83.990917   2.876336  10.966033             NaN                 127500.0
# 2        NaN        NaN        NaN             NaN                      NaN
# 3        NaN        NaN        NaN             NaN                      NaN
# 4        NaN        NaN        NaN             NaN                      NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# Let's take a look at the null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263121 entries, 0 to 263120
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Description               263121 non-null  object
#  1   Inside/Outside            263121 non-null  object
#  2   Weapon                    263121 non-null  object
#  3   Post                      263121 non-null  float64
#  4   District                  263121 non-null  object
#  5   Neighborhood              263121 non-null  object
#  6   Longitude                 263121 non-null  float64
#  7   Latitude                  263121 non-null  float64
#  8   Premise                   263121 non-null  object
#  9   Season                    263121 non-null  object
#  10  Month                     263121 non-null  int64
#  11  Hour                      263121 non-null  int64
#  12  Year                      263121 non-null  int64
#  13  CSA                       111993 non-null  object
#  14  median_household_income   111993 non-null  float64
#  15  households_below_poverty  51833 non-null   float64
#  16  perc18_24                 51833 non-null   float64
#  17  perc25_64                 51833 non-null   float64
#  18  perc65up                  51833 non-null   float64
#  19  perc_asian                51833 non-null   float64
#  20  perc_aa                   51833 non-null   float64
#  21  perc_hisp                 51833 non-null   float64
#  22  pwhi                      51833 non-null   float64
#  23  num_households            0 non-null       float64
#  24  median_price_homes_sold   111993 non-null  float64
# dtypes: float64(14), int64(3), object(8)
# memory usage: 50.2+ MB

# %% [markdown]
# Looks like they're all part of the new data. However, this new data does actually look like it can be imputed! Let's clean first a bit.

# %%
df.CSA.value_counts()
# Out:
# Downtown/Seton Hill                      9603
# Cedonia/Frankford                        6850
# Sandtown-Winchester/Harlem Park          6305
# Brooklyn/Curtis Bay/Hawkins Point        6291
# Belair-Edison                            5722
# Inner Harbor/Federal Hill                4695
# Medfield/Hampden/Woodberry/Remington     4430
# Upton/Druid Heights                      4353
# Penn North/Reservoir Hill                3952
# Cherry Hill                              3932
# Canton                                   3653
# Greater Charles Village/Barclay          3640
# Howard Park/West Arlington               3479
# Fells Point                              3218
# Washington Village/Pigtown               3119
# Greater Mondawmin                        3104
# Morrell Park/Violetville                 2869
# Westport/Mount Winans/Lakeland           2847
# Poppleton/The Terraces/Hollins Market    2786
# Allendale/Irvington/S. Hilton            2733
# Glen-Fallstaff                           2441
# Oldtown/Middle East                      2275
# Highlandtown                             1777
# Forest Park/Walbrook                     1587
# Dorchester/Ashburton                     1535
# North Baltimore/Guilford/Homeland        1493
# Beechfield/Ten Hills/West Hills          1490
# Loch Raven                               1465
# Clifton-Berea                            1332
# Mount Washington/Coldspring              1137
# Greater Rosemont                         1099
# Lauraville                               1095
# Edmondson Village                         964
# South Baltimore                           926
# Harbor East/Little Italy                  762
# Greater Roland Park/Poplar Hill           694
# Cross-Country/Cheswolde                   679
# Chinquapin Park/Belvedere                 676
# Dickeyville/Franklintown                  373
# Orangeville/East Highlandtown             358
# Patterson Park North & East               254
# Name: CSA, dtype: int64

# %% [markdown]
# This looks like the column used to match with neighborhoods.

# %%
df[["CSA", "Neighborhood"]].head(20)
# Out:
#                                   CSA              Neighborhood
# 0   Brooklyn/Curtis Bay/Hawkins Point                  Brooklyn
# 1           Penn North/Reservoir Hill            Reservoir Hill
# 2                                 NaN            Winston-Govans
# 3                                 NaN          Carrollton Ridge
# 4                                 NaN             Downtown West
# 5                         Cherry Hill               Cherry Hill
# 6                              Canton                    Canton
# 7                 Upton/Druid Heights                     Upton
# 8                                 NaN             Windsor Hills
# 9                       Clifton-Berea                     Berea
# 10                                NaN             Windsor Hills
# 11                                NaN                  Edgewood
# 12                                NaN             Windsor Hills
# 13                  Cedonia/Frankford                 Frankford
# 14                                NaN  Holabird Industrial Park
# 15                                NaN                    Oliver
# 16                                NaN                    Oliver
# 17                                NaN              Madison Park
# 18                                NaN           Washington Hill
# 19                                NaN                Waltherson

# %% [markdown]
# Yep. Can drop this.

# %%
df = df.drop(columns=["CSA"])

# %% [markdown]
# The num_households variable looks like it is all null. Drop.

# %%
df.num_households.value_counts()
# Out:
# Series([], Name: num_households, dtype: int64)

# %%
df = df.drop(columns=["num_households"])

# %%
df.describe()
# Out:
#                 Post     Longitude       Latitude          Month  \
# count  263121.000000  263121.00000  263121.000000  263121.000000
# mean      505.839732     -76.61747      39.307456       6.515622
# std       260.790134       0.04222       0.029536       3.295076
# min       111.000000     -76.71128      39.200410       1.000000
# 25%       242.000000     -76.64842      39.288340       4.000000
# 50%       511.000000     -76.61401      39.303680       7.000000
# 75%       731.000000     -76.58749      39.327890       9.000000
# max       943.000000     -76.52977      39.371980      12.000000
#
#                 Hour           Year  median_household_income  \
# count  263121.000000  263121.000000            111993.000000
# mean       13.293242    2014.307494             44762.632048
# std         6.768847       1.626543             20912.174139
# min         0.000000    2012.000000             13478.164522
# 25%         9.000000    2013.000000             33526.364650
# 50%        15.000000    2014.000000             39495.628472
# 75%        19.000000    2016.000000             48731.137681
# max        23.000000    2017.000000            113496.137874
#
#        households_below_poverty     perc18_24     perc25_64      perc65up  \
# count              51833.000000  51833.000000  51833.000000  51833.000000
# mean                  19.882242     10.859386     57.518633     11.076125
# std                   12.669277      5.238397      8.493396      4.591031
# min                    0.811908      2.901160     43.598031      4.414003
# 25%                    7.528577      8.233108     51.519081      7.864742
# 50%                   18.816794      9.371567     55.578669     10.396187
# 75%                   26.333747     11.228641     63.126900     13.708109
# max                   48.720930     30.297173     77.957456     26.968635
#
#          perc_asian       perc_aa     perc_hisp          pwhi  \
# count  51833.000000  51833.000000  51833.000000  51833.000000
# mean       3.570093     58.842530      4.356489     30.502446
# std        4.190585     33.004647      4.240844     27.629849
# min        0.000000      1.726247      0.017008      0.358262
# 25%        0.547692     29.776084      1.406284      4.362915
# 50%        1.945525     69.781797      3.381459     20.776607
# 75%        4.742416     88.789903      5.362851     46.676814
# max       16.255931     97.440983     35.227378     90.032994
#
#        median_price_homes_sold
# count            111993.000000
# mean             123883.995598
# std               91443.474131
# min               12550.000000
# 25%               47050.000000
# 50%               88500.000000
# 75%              190000.000000
# max              377500.000000

# %% [markdown]
# I'm not too happy about this many missing values. However, the nature of these could actually lend itself to imputation. Let's give it a try.
# Sklearn's iterative imputer says it is experimental. Let's try out miceforest. It uses the MICE algorithm with random forest, as the name implies.

# %%
import miceforest as mf

# %% [markdown]
# We need to convert the categorical variables to their labels from before. This is the unencoded data.

# %%
bpd_df = pd.get_dummies(df, columns=["Inside/Outside"],drop_first=True)
bpd_df= bpd_df.rename(columns={"Inside/Outside_Outside":"Outside"})

# %%
bpd_df = pd.get_dummies(bpd_df, columns=["Weapon","Season"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
Description = pd.read_csv("../data/Description_decoder_2.csv", header=None)
Premise = pd.read_csv("../data/Premise_decoder.csv", header=None)
Neigh = pd.read_csv("../data/Neighborhood_decoder.csv", header=None)
District = pd.read_csv("../data/District_decoder.csv", header=None)

# %% [markdown]
# Should we drop year?

# %%
are_there_years = df[df.median_household_income.notnull()]
are_there_years.Year.value_counts()
# Out:
# 2012    20739
# 2016    20394
# 2013    20340
# 2015    20030
# 2014    19081
# 2017    11409
# Name: Year, dtype: int64

# %% [markdown]
# Hmm no, there are multiple years, and will be useful to impute!

# %%
le.fit(Description[0])
le.classes_
# Out:
# array(['AGG. ASSAULT', 'ARSON', 'ASSAULT BY THREAT', 'AUTO THEFT',
#        'BURGLARY', 'COMMON ASSAULT', 'HOMICIDE', 'LARCENY',
#        'LARCENY FROM AUTO', 'ROBBERY - CARJACKING',
#        'ROBBERY - COMMERCIAL', 'ROBBERY - RESIDENCE', 'ROBBERY - STREET',
#        'SEXUAL ASSULT', 'SHOOTING'], dtype=object)

# %%
le.classes_[13] = "RAPE"
le.classes_
# Out:
# array(['AGG. ASSAULT', 'ARSON', 'ASSAULT BY THREAT', 'AUTO THEFT',
#        'BURGLARY', 'COMMON ASSAULT', 'HOMICIDE', 'LARCENY',
#        'LARCENY FROM AUTO', 'ROBBERY - CARJACKING',
#        'ROBBERY - COMMERCIAL', 'ROBBERY - RESIDENCE', 'ROBBERY - STREET',
#        'RAPE', 'SHOOTING'], dtype=object)

# %%
bpd_df["Description"]=le.transform(bpd_df["Description"])

# %%
le.fit(Neigh[0])
bpd_df["Neighborhood"]=le.transform(bpd_df["Neighborhood"])

# %%
le.fit(Premise[0])
bpd_df["Premise"]=le.transform(bpd_df["Premise"])

# %%
le.fit(District[0])
bpd_df["District"]=le.transform(bpd_df["District"])

# %%
bpd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263121 entries, 0 to 263120
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Description               263121 non-null  int32
#  1   Post                      263121 non-null  float64
#  2   District                  263121 non-null  int32
#  3   Neighborhood              263121 non-null  int32
#  4   Longitude                 263121 non-null  float64
#  5   Latitude                  263121 non-null  float64
#  6   Premise                   263121 non-null  int32
#  7   Month                     263121 non-null  int64
#  8   Hour                      263121 non-null  int64
#  9   Year                      263121 non-null  int64
#  10  median_household_income   111993 non-null  float64
#  11  households_below_poverty  51833 non-null   float64
#  12  perc18_24                 51833 non-null   float64
#  13  perc25_64                 51833 non-null   float64
#  14  perc65up                  51833 non-null   float64
#  15  perc_asian                51833 non-null   float64
#  16  perc_aa                   51833 non-null   float64
#  17  perc_hisp                 51833 non-null   float64
#  18  pwhi                      51833 non-null   float64
#  19  median_price_homes_sold   111993 non-null  float64
#  20  Outside                   263121 non-null  uint8
#  21  Weapon_FIREARM            263121 non-null  uint8
#  22  Weapon_HANDS              263121 non-null  uint8
#  23  Weapon_KNIFE              263121 non-null  uint8
#  24  Weapon_NONE               263121 non-null  uint8
#  25  Weapon_OTHER              263121 non-null  uint8
#  26  Season_autumn             263121 non-null  uint8
#  27  Season_spring             263121 non-null  uint8
#  28  Season_summer             263121 non-null  uint8
#  29  Season_winter             263121 non-null  uint8
# dtypes: float64(13), int32(4), int64(3), uint8(10)
# memory usage: 38.6 MB

# %% [markdown]
# Looks good. Let's do it.

# %%
kernel = mf.MultipleImputedKernel(data=bpd_df, save_all_iterations=True,random_state=42069)

# %% [markdown]
# This should save the iterations of the MICE algorithm. We can then compare the imputed values to see if they are similar, giving us some confidence.

# %%
import timeit

# %%
start = timeit.default_timer()
kernel.mice(3,verbose=True,n_jobs=-1)
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Dataset 0
# 1  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 2  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 3  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Dataset 1
# 1  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 2  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 3  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Dataset 2
# 1  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 2  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 3  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Dataset 3
# 1  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 2  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 3  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Dataset 4
# 1  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 2  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 3  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Time:  430.18356719999997

# %%
kernel.plot_correlations(wspace=0.4,hspace=0.5)
kernel.plot_mean_convergence()

# %% [markdown]
# Looks like we're actually getting decent results from the imputation! The graphs are hard to see and I can't make them bigger, but the correlations between the 5 imputed datasets are fairly high, and are converging. Let's do it for 5 more iterations.

# %%
start = timeit.default_timer()
kernel.mice(5,verbose=True,n_jobs=-1)
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Dataset 0
# 4  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 5  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 6  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 7  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 8  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Dataset 1
# 4  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 5  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 6  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 7  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 8  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Dataset 2
# 4  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 5  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 6  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 7  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 8  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Dataset 3
# 4  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 5  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 6  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 7  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 8  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Dataset 4
# 4  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 5  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 6  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 7  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# 8  | median_household_income | households_below_poverty | perc18_24 | perc25_64 | perc65up | perc_asian | perc_aa | perc_hisp | pwhi | median_price_homes_sold
# Time:  737.1760977000001

# %%
kernel.plot_correlations(wspace=0.4,hspace=0.5)
kernel.plot_mean_convergence()

# %% [markdown]
# Very nice

# %%
completed_data = kernel.complete_data(0)

# %%
completed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263121 entries, 0 to 263120
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Description               263121 non-null  int32
#  1   Post                      263121 non-null  float64
#  2   District                  263121 non-null  int32
#  3   Neighborhood              263121 non-null  int32
#  4   Longitude                 263121 non-null  float64
#  5   Latitude                  263121 non-null  float64
#  6   Premise                   263121 non-null  int32
#  7   Month                     263121 non-null  int64
#  8   Hour                      263121 non-null  int64
#  9   Year                      263121 non-null  int64
#  10  median_household_income   263121 non-null  float64
#  11  households_below_poverty  263121 non-null  float64
#  12  perc18_24                 263121 non-null  float64
#  13  perc25_64                 263121 non-null  float64
#  14  perc65up                  263121 non-null  float64
#  15  perc_asian                263121 non-null  float64
#  16  perc_aa                   263121 non-null  float64
#  17  perc_hisp                 263121 non-null  float64
#  18  pwhi                      263121 non-null  float64
#  19  median_price_homes_sold   263121 non-null  float64
#  20  Outside                   263121 non-null  uint8
#  21  Weapon_FIREARM            263121 non-null  uint8
#  22  Weapon_HANDS              263121 non-null  uint8
#  23  Weapon_KNIFE              263121 non-null  uint8
#  24  Weapon_NONE               263121 non-null  uint8
#  25  Weapon_OTHER              263121 non-null  uint8
#  26  Season_autumn             263121 non-null  uint8
#  27  Season_spring             263121 non-null  uint8
#  28  Season_summer             263121 non-null  uint8
#  29  Season_winter             263121 non-null  uint8
# dtypes: float64(13), int32(4), int64(3), uint8(10)
# memory usage: 38.6 MB

# %%
completed_data.to_csv("../data/BPD_CRIME_DATA_W_IMPUTED_DEMO.csv")

# %%
import pickle

# %%
pickle.dump(kernel, open("MICE_MODEL.sav","wb"))
